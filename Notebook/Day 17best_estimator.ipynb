# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
# 1. Load Data
data = load_breast_cancer()
X, y = data.data, data.target
# 2. Define the Search Space
param_grid = {
'n_estimators': [50, 100, 200],
'max_depth': [None, 10, 20],
'min_samples_split': [2, 5, 10]
}
# 3. Initialize GridSearch with 3-Fold Cross-Validation
rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
cv=3, scoring='accuracy', verbose=1)
# 4. Run the search
grid_search.fit(X, y)
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Cross-Validation Score: {grid_search.best_score_:.4f}")
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Best Parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}
# Best Cross-Validation Score: 0.9631

# %%
import joblib
best_model = grid_search.best_estimator_

joblib.dump(best_model, "best_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %% [markdown]
# ### Reflection

# %% [markdown]
# GridSearchCV evaluates all possible permutations of hyperparameters.
# For example, if there are 5 hyperparameters with 10 options per parameter, the number of permutations will be:
# 10 × 10 × 10 × 10 × 10 = 100,000 combinations
# It becomes highly computational to do that.
# For this reason, RandomizedSearchCV should be used when dealing with large data sets since it takes a sample of possible combinations and saves much computation time.
